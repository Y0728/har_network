# %%
from pandas import Series, DataFrame
import  pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
from pylab import mpl

mpl.rcParams['font.sans-serif'] = ['SimHei'] #中文显示问题

# %% [markdown]
# 验证时空结合有效性

# %%
data={'M_(s-P)':{'站立':62.67, '跳跃':75.41, '坐下':76.90, '跌倒':53.21,	'跑步':62.89, '走路':93.69, '弯腰':45.74, '实例准确率':68.21},
    'M_t':{'站立':94.55, '跳跃':77.48, '坐下':83.33, '跌倒':67.87,	'跑步':80.95, '走路':93.89, '弯腰':67.57, '实例准确率':81.79},
    'M_(s&t)':{'站立':94.80, '跳跃':79.30, '坐下':94.85, '跌倒':74.78,	'跑步':97.84, '走路':99.32, '弯腰':85.21, '实例准确率':90.46}}
print(DataFrame(data))
# Out:
#        M_(s-P)    M_t  M_(s&t)
# 站立       62.67  94.55    94.80
# 跳跃       75.41  77.48    79.30
# 坐下       76.90  83.33    94.85
# 跌倒       53.21  67.87    74.78
# 跑步       62.89  80.95    97.84
# 走路       93.69  93.89    99.32
# 弯腰       45.74  67.57    85.21
# 实例准确率    68.21  81.79    90.46

# %%
# data={'M_(s-P)':{'站立':62.67, '跳跃':75.41, '坐下':76.90, '跌倒':53.21,	'跑步':62.89, '走路':93.69, '弯腰':45.74, '实例准确率':68.21},
#     'M_t':{'站立':94.55, '跳跃':77.48, '坐下':83.33, '跌倒':67.87,	'跑步':80.95, '走路':93.89, '弯腰':67.57, '实例准确率':81.79},
#     'M_(s&t)':{'站立':94.80, '跳跃':79.30, '坐下':94.85, '跌倒':74.78,	'跑步':97.84, '走路':99.32, '弯腰':85.21, '实例准确率':90.46}}
# data=np.array([['M_(s-P)',62.67, 75.41,	76.90,	53.21,	62.89,	93.69,	45.74, 68.21],
#                ['M_t',94.55,	77.48,	83.33,	67.87,	80.95,	93.89,	67.57,	81.79],
#                ['M_(s&t)',94.80,	79.30,	94.85,	74.78,	97.84,	99.32,	85.21,	90.46]])
data = {'Accuracy (%)': [62.67, 75.41,	76.90,	53.21,	62.89,	93.69,	45.74, 68.21,
                  94.55,	77.48,	83.33,	67.87,	80.95,	93.89,	67.57,	81.79,
                  94.80,	79.30,	94.85,	74.78,	97.84,	99.32,	85.21,	90.46] }
# col_name=['']
# df=DataFrame(data,columns=['模型','站立','跳跃','坐下','跌倒','跑步','行走',	'弯腰','实例准确率'])
df=DataFrame(data)
# act=['站立','跳跃','坐下','跌倒','跑步','行走',	'弯腰','实例准确率']
act=['Stand','Jump','Sit','Fall','Run','Walk','Bend','Instance_Acc']

df['Model']=[None for i in range(len(df))]
df['Model'][0:int(len(df)/3)]='M_(s-P)'
df['Model'][int(len(df)/3):int(len(df)/3*2)]='M_t'
df['Model'][int(len(df)/3)*2:int(len(df))]='M_(s&t)'
df['Activity']=[None for i in range(len(df))]
df['Activity'][0:int(len(df)/3)]=act
df['Activity'][int(len(df)/3):int(len(df)/3*2)]=act
df['Activity'][int(len(df)/3)*2:int(len(df))]=act

print(df)
# Out:
#     Accuracy (%)    Model      Activity
# 0          62.67  M_(s-P)         Stand
# 1          75.41  M_(s-P)          Jump
# 2          76.90  M_(s-P)           Sit
# 3          53.21  M_(s-P)          Fall
# 4          62.89  M_(s-P)           Run
# 5          93.69  M_(s-P)          Walk
# 6          45.74  M_(s-P)          Bend
# 7          68.21  M_(s-P)  Instance_Acc
# 8          94.55      M_t         Stand
# 9          77.48      M_t          Jump
# 10         83.33      M_t           Sit
# 11         67.87      M_t          Fall
# 12         80.95      M_t           Run
# 13         93.89      M_t          Walk
# 14         67.57      M_t          Bend
# 15         81.79      M_t  Instance_Acc
# 16         94.80  M_(s&t)         Stand
# 17         79.30  M_(s&t)          Jump
# 18         94.85  M_(s&t)           Sit
# 19         74.78  M_(s&t)          Fall
# 20         97.84  M_(s&t)           Run
# 21         99.32  M_(s&t)          Walk
# 22         85.21  M_(s&t)          Bend
# 23         90.46  M_(s&t)  Instance_Acc
# <ipython-input-4-6d4c8f09185a>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Model'][0:int(len(df)/3)]='M_(s-P)'
# <ipython-input-4-6d4c8f09185a>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Model'][int(len(df)/3):int(len(df)/3*2)]='M_t'
# <ipython-input-4-6d4c8f09185a>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Model'][int(len(df)/3)*2:int(len(df))]='M_(s&t)'
# <ipython-input-4-6d4c8f09185a>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Activity'][0:int(len(df)/3)]=act
# <ipython-input-4-6d4c8f09185a>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Activity'][int(len(df)/3):int(len(df)/3*2)]=act
# <ipython-input-4-6d4c8f09185a>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Activity'][int(len(df)/3)*2:int(len(df))]=act

# %% [raw]
# 62.67%	75.41%	76.90%	53.21%	62.89%	93.69%	45.74%  68.21%
# 94.55%	77.48%	83.33%	67.87%	80.95%	93.89%	67.57%	81.79%
# 94.80%	79.30%	94.85%	74.78%	97.84%	99.32%	85.21%	90.46%

# %%
plt.figure(figsize=(12,10))
sns.set(style='whitegrid')
plt.tick_params(axis='x', labelsize=16)
plt.tick_params(axis='y', labelsize=16)
ax=sns.barplot(data=df,x='Activity',y='Accuracy (%)',hue='Model')
ax.set_xlabel('Activity',fontsize=16)
ax.set_ylabel('Accuracy (%)',fontsize=16)
plt.legend(title='Model',fontsize=16,title_fontsize=16,bbox_to_anchor=(1, 1))
# plt.title()
plt.show()
plt.savefig('/home/mz/Human_activity/yj/har_network/res_vis/pics/验证时空结合有效性.png')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-5-641f0187e60b> in <module>
#       9 # plt.title()
#      10 plt.show()
# ---> 11 plt.savefig('/home/mz/Human_activity/yj/har_network/res_vis/pics/验证时空结合有效性.png')
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/pyplot.py in savefig(*args, **kwargs)
#     857 def savefig(*args, **kwargs):
#     858     fig = gcf()
# --> 859     res = fig.savefig(*args, **kwargs)
#     860     fig.canvas.draw_idle()   # need this if 'transparent=True' to reset colors
#     861     return res
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/figure.py in savefig(self, fname, transparent, **kwargs)
#    2309                 patch.set_edgecolor('none')
#    2310
# -> 2311         self.canvas.print_figure(fname, **kwargs)
#    2312
#    2313         if transparent:
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2208
#    2209             try:
# -> 2210                 result = print_method(
#    2211                     filename,
#    2212                     dpi=dpi,
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/backend_bases.py in wrapper(*args, **kwargs)
#    1637             kwargs.pop(arg)
#    1638
# -> 1639         return func(*args, **kwargs)
#    1640
#    1641     return wrapper
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/backends/backend_agg.py in print_png(self, filename_or_obj, metadata, pil_kwargs, *args)
#     508         """
#     509         FigureCanvasAgg.draw(self)
# --> 510         mpl.image.imsave(
#     511             filename_or_obj, self.buffer_rgba(), format="png", origin="upper",
#     512             dpi=self.figure.dpi, metadata=metadata, pil_kwargs=pil_kwargs)
#
# ~/anaconda3/lib/python3.8/site-packages/matplotlib/image.py in imsave(fname, arr, vmin, vmax, cmap, format, origin, dpi, metadata, pil_kwargs)
#    1609         pil_kwargs.setdefault("format", format)
#    1610         pil_kwargs.setdefault("dpi", (dpi, dpi))
# -> 1611         image.save(fname, **pil_kwargs)
#    1612
#    1613
#
# ~/anaconda3/lib/python3.8/site-packages/PIL/Image.py in save(self, fp, format, **params)
#    2167                 fp = builtins.open(filename, "r+b")
#    2168             else:
# -> 2169                 fp = builtins.open(filename, "w+b")
#    2170
#    2171         try:
#
# FileNotFoundError: [Errno 2] No such file or directory: '/home/mz/Human_activity/yj/har_network/res_vis/pics/验证时空结合有效性.png'

# %%
import os
print(os.getcwd())

# %%
79.58, 80.00, 85.37, 69.88, 82.25, 99.10, 74.36, 82.54
94.80, 68.53, 89.19, 65.99, 60.17, 84.62, 54.68, 78.11

data = {'Accuracy (%)': [79.58, 80.00, 85.37, 69.88, 82.25, 99.10, 74.36, 82.54,
                  94.80, 68.53, 89.19, 65.99, 60.17, 84.62, 54.68, 78.11,
                  94.80,	79.30,	94.85,	74.78,	97.84,	99.32,	85.21,	90.46] }
# col_name=['']
# df=DataFrame(data,columns=['模型','站立','跳跃','坐下','跌倒','跑步','行走',	'弯腰','实例准确率'])
df=DataFrame(data)
# act=['站立','跳跃','坐下','跌倒','跑步','行走',	'弯腰','实例准确率']
act=['Stand','Jump','Sit','Fall','Run','Walk','Bend','Instance_Acc']

df['Model']=[None for i in range(len(df))]
df['Model'][0:int(len(df)/3)]='M_)'
df['Model'][int(len(df)/3):int(len(df)/3*2)]='M_T'
df['Model'][int(len(df)/3)*2:int(len(df))]='M_(P&T)'
df['Activity']=[None for i in range(len(df))]
df['Activity'][0:int(len(df)/3)]=act
df['Activity'][int(len(df)/3):int(len(df)/3*2)]=act
df['Activity'][int(len(df)/3)*2:int(len(df))]=act

print(df)

# %% [markdown]
# ## 三种方法的准确率对比

# %%
# data={'M_(s-P)':{'站立':62.67, '跳跃':75.41, '坐下':76.90, '跌倒':53.21,	'跑步':62.89, '走路':93.69, '弯腰':45.74, '实例准确率':68.21},
#     'M_t':{'站立':94.55, '跳跃':77.48, '坐下':83.33, '跌倒':67.87,	'跑步':80.95, '走路':93.89, '弯腰':67.57, '实例准确率':81.79},
#     'M_(s&t)':{'站立':94.80, '跳跃':79.30, '坐下':94.85, '跌倒':74.78,	'跑步':97.84, '走路':99.32, '弯腰':85.21, '实例准确率':90.46}}
# data=np.array([['M_(s-P)',62.67, 75.41,	76.90,	53.21,	62.89,	93.69,	45.74, 68.21],
#                ['M_t',94.55,	77.48,	83.33,	67.87,	80.95,	93.89,	67.57,	81.79],
#                ['M_(s&t)',94.80,	79.30,	94.85,	74.78,	97.84,	99.32,	85.21,	90.46]])
data = {'Accuracy (%)': [45.92, 35.84, 63.93, 28.39, 37.66, 92.19, 56.17, 55.70,
                  67.08, 58.18, 79.13, 53.89, 76.19, 92.19, 54.95, 70.41,
                  94.80,	79.30,	94.85,	74.78,	97.84,	99.32,	85.21,	90.46] }
# col_name=['']
# df=DataFrame(data,columns=['模型','站立','跳跃','坐下','跌倒','跑步','行走',	'弯腰','实例准确率'])
df=DataFrame(data)
# act=['站立','跳跃','坐下','跌倒','跑步','行走',	'弯腰','实例准确率']
act=['Stand','Jump','Sit','Fall','Run','Walk','Bend','Instance_Acc']

df['Model']=[None for i in range(len(df))]
df['Model'][0:int(len(df)/3)]='RadHAR'
df['Model'][int(len(df)/3):int(len(df)/3*2)]='MMPoint-GNN'
df['Model'][int(len(df)/3)*2:int(len(df))]='Ours'
df['Activity']=[None for i in range(len(df))]
df['Activity'][0:int(len(df)/3)]=act
df['Activity'][int(len(df)/3):int(len(df)/3*2)]=act
df['Activity'][int(len(df)/3)*2:int(len(df))]=act

print(df)
# Out:
#     Accuracy (%)        Model      Activity
# 0          45.92       RadHAR         Stand
# 1          35.84       RadHAR          Jump
# 2          63.93       RadHAR           Sit
# 3          28.39       RadHAR          Fall
# 4          37.66       RadHAR           Run
# 5          92.19       RadHAR          Walk
# 6          56.17       RadHAR          Bend
# 7          55.70       RadHAR  Instance_Acc
# 8          67.08  MMPoint-GNN         Stand
# 9          58.18  MMPoint-GNN          Jump
# 10         79.13  MMPoint-GNN           Sit
# 11         53.89  MMPoint-GNN          Fall
# 12         76.19  MMPoint-GNN           Run
# 13         92.19  MMPoint-GNN          Walk
# 14         54.95  MMPoint-GNN          Bend
# 15         70.41  MMPoint-GNN  Instance_Acc
# 16         94.80         Ours         Stand
# 17         79.30         Ours          Jump
# 18         94.85         Ours           Sit
# 19         74.78         Ours          Fall
# 20         97.84         Ours           Run
# 21         99.32         Ours          Walk
# 22         85.21         Ours          Bend
# 23         90.46         Ours  Instance_Acc
# <ipython-input-6-2cf586126ada>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Model'][0:int(len(df)/3)]='RadHAR'
# <ipython-input-6-2cf586126ada>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Model'][int(len(df)/3):int(len(df)/3*2)]='MMPoint-GNN'
# <ipython-input-6-2cf586126ada>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Model'][int(len(df)/3)*2:int(len(df))]='Ours'
# <ipython-input-6-2cf586126ada>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Activity'][0:int(len(df)/3)]=act
# <ipython-input-6-2cf586126ada>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Activity'][int(len(df)/3):int(len(df)/3*2)]=act
# <ipython-input-6-2cf586126ada>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Activity'][int(len(df)/3)*2:int(len(df))]=act

# %%
plt.figure(figsize=(12,10))
sns.set(style='whitegrid')
plt.tick_params(axis='x', labelsize=16)
plt.tick_params(axis='y', labelsize=16)
ax=sns.barplot(data=df,x='Activity',y='Accuracy (%)',hue='Model')
ax.set_xlabel('Activity',fontsize=16)
ax.set_ylabel('Accuracy (%)',fontsize=16)
plt.legend(title='Model',fontsize=16,title_fontsize=16,bbox_to_anchor=(1, 1))
# plt.title()
plt.show()
# plt.savefig('/home/mz/Human_activity/yj/har_network/res_vis/pics/验证时空结合有效性.png')

# %% [markdown]
# ## 可扩展性对比

# %%
# data={'M_(s-P)':{'站立':62.67, '跳跃':75.41, '坐下':76.90, '跌倒':53.21,	'跑步':62.89, '走路':93.69, '弯腰':45.74, '实例准确率':68.21},
#     'M_t':{'站立':94.55, '跳跃':77.48, '坐下':83.33, '跌倒':67.87,	'跑步':80.95, '走路':93.89, '弯腰':67.57, '实例准确率':81.79},
#     'M_(s&t)':{'站立':94.80, '跳跃':79.30, '坐下':94.85, '跌倒':74.78,	'跑步':97.84, '走路':99.32, '弯腰':85.21, '实例准确率':90.46}}
# data=np.array([['M_(s-P)',62.67, 75.41,	76.90,	53.21,	62.89,	93.69,	45.74, 68.21],
#                ['M_t',94.55,	77.48,	83.33,	67.87,	80.95,	93.89,	67.57,	81.79],
#                ['M_(s&t)',94.80,	79.30,	94.85,	74.78,	97.84,	99.32,	85.21,	90.46]])
data = {'Accuracy (%)': [100, 75.48, 60, 55.70,
                  100, 91.87, 78.17, 70.41,
                  100, 95.64, 91.76,	90.46] }
# col_name=['']
# df=DataFrame(data,columns=['模型','站立','跳跃','坐下','跌倒','跑步','行走',	'弯腰','实例准确率'])
df=DataFrame(data)
# act=['站立','跳跃','坐下','跌倒','跑步','行走',	'弯腰','实例准确率']
act=['1','3','5','7']

df['Model']=[None for i in range(len(df))]
df['Model'][0:int(len(df)/3)]='RadHAR'
df['Model'][int(len(df)/3):int(len(df)/3*2)]='MMPoint-GNN'
df['Model'][int(len(df)/3)*2:int(len(df))]='Ours'
df['Activity']=[None for i in range(len(df))]
df['Activity'][0:int(len(df)/3)]=act
df['Activity'][int(len(df)/3):int(len(df)/3*2)]=act
df['Activity'][int(len(df)/3)*2:int(len(df))]=act

print(df)
# Out:
#     Accuracy (%)        Model Activity
# 0         100.00       RadHAR        1
# 1          75.48       RadHAR        3
# 2          60.00       RadHAR        5
# 3          55.70       RadHAR        7
# 4         100.00  MMPoint-GNN        1
# 5          91.87  MMPoint-GNN        3
# 6          78.17  MMPoint-GNN        5
# 7          70.41  MMPoint-GNN        7
# 8         100.00         Ours        1
# 9          95.64         Ours        3
# 10         91.76         Ours        5
# 11         90.46         Ours        7
# <ipython-input-8-95677cabf862>:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Model'][0:int(len(df)/3)]='RadHAR'
# <ipython-input-8-95677cabf862>:18: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Model'][int(len(df)/3):int(len(df)/3*2)]='MMPoint-GNN'
# <ipython-input-8-95677cabf862>:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Model'][int(len(df)/3)*2:int(len(df))]='Ours'
# <ipython-input-8-95677cabf862>:21: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Activity'][0:int(len(df)/3)]=act
# <ipython-input-8-95677cabf862>:22: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Activity'][int(len(df)/3):int(len(df)/3*2)]=act
# <ipython-input-8-95677cabf862>:23: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['Activity'][int(len(df)/3)*2:int(len(df))]=act

# %% [markdown]
# 样例：https://zhuanlan.zhihu.com/p/89353885
# # 点图细节设置
#
# sns.pointplot(x="class", y="survived", hue="sex", data=titanic,
#               palette={"male": "g", "female": "m"},
#               markers=["^", "o"], linestyles=["-", "--"],
#              scale=1.5)
#
# # palette 通过调色板来设置颜色，
# # markers设置点的形状，
# # linestyles设置显的风格，
# # scale设置线条的粗细
#
# plt.show()

# %%
plt.figure(figsize=(12,10))
sns.set(style='whitegrid')
plt.tick_params(axis='x', labelsize=16)
plt.tick_params(axis='y', labelsize=16)
# ax=sns.barplot(data=df,x='Activity',y='Accuracy (%)',hue='Model')
ax=sns.pointplot(data=df,x='Activity',y='Accuracy (%)',hue='Model',scale=3)
ax.set_xlabel('#Activity',fontsize=16)
ax.set_ylabel('Accuracy (%)',fontsize=16)
plt.legend(title='Model',fontsize=16,title_fontsize=16,bbox_to_anchor=(1, 1))
# plt.title()
plt.show()
# plt.savefig('/home/mz/Human_activity/yj/har_network/res_vis/pics/验证时空结合有效性.png')
